# %%
import pandas as pd
import numpy as np
import PIL
import os
from pathlib import Path

index_dataset20 = pd.read_csv("./hc-features/dataset20_index_features.csv")
index_dataset20.drop(columns=["Unnamed: 0"],inplace=True)
print(index_dataset20.columns.values)
for i,column in enumerate(index_dataset20.columns.values[2:-1]):
    index_dataset20.columns.values[i+2] = f"feature{i+1}"
    print(column)
index_dataset20.to_csv("./weka_dataset20.csv",index=False)
# Out:
# ['y' 'x' 'Unnamed: 3' 'Unnamed: 4' 'Unnamed: 5' 'Unnamed: 6' 'Unnamed: 7'
#  'Unnamed: 8' 'Unnamed: 9' 'Unnamed: 10' 'Unnamed: 11' 'Unnamed: 12'
#  'Unnamed: 13' 'Unnamed: 14' 'Unnamed: 15' 'Unnamed: 16' 'Unnamed: 17'
#  'Unnamed: 18' 'Unnamed: 19' 'Unnamed: 20' 'Unnamed: 21' 'Unnamed: 22'
#  'Unnamed: 23' 'Unnamed: 24' 'Unnamed: 25' 'Unnamed: 26' 'Unnamed: 27'
#  'Unnamed: 28' 'Unnamed: 29' 'Unnamed: 30' 'Unnamed: 31' 'Unnamed: 32'
#  'Unnamed: 33' 'Unnamed: 34' 'Unnamed: 35' 'Unnamed: 36' 'Unnamed: 37'
#  'Unnamed: 38' 'Unnamed: 39' 'Unnamed: 40' 'Unnamed: 41' 'Unnamed: 42'
#  'Unnamed: 43' 'Unnamed: 44' 'Unnamed: 45' 'Unnamed: 46' 'Unnamed: 47'
#  'Unnamed: 48' 'Unnamed: 49' 'Unnamed: 50' 'Unnamed: 51' 'Unnamed: 52'
#  'class']
# Unnamed: 3
# Unnamed: 4
# Unnamed: 5
# Unnamed: 6
# Unnamed: 7
# Unnamed: 8
# Unnamed: 9
# Unnamed: 10
# Unnamed: 11
# Unnamed: 12
# Unnamed: 13
# Unnamed: 14
# Unnamed: 15
# Unnamed: 16
# Unnamed: 17
# Unnamed: 18
# Unnamed: 19
# Unnamed: 20
# ...
