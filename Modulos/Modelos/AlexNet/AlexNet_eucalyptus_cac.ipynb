# %% [markdown]
# # Training and validation

# %%
import torch
from Utils import AnaliseGraficaVal, train, eval, fix_random_seed, predict
# Importe a classe que criamos anteriormente
from Datasets import Eucalyptus_openset_loader

from Modelos import AlexNet_cac
from torchvision import transforms
from torchvision.models import AlexNet_Weights
import torch.nn as nn
import torch.optim as optim
from Utils.Nomes import NOMES
from Utils import CACLoss,train_cac,eval_cac
import gc
import os

# Configurações iniciais
fix_random_seed(42)
device = "cuda:0" if torch.cuda.is_available() else "cpu"

lr = 0.0001
epochs = 30
bs = 64
num_classes = 2
n_folds = 5
dataset= "dataset-1"
alpha=5
lbda=0.1

weights = AlexNet_Weights.IMAGENET1K_V1


# 2. Inicialização do Loader customizado
data_manager = Eucalyptus_openset_loader(bs=bs,dataset=dataset)
model_name = "AlexNet"
model_dir = f"/home/alexandreselani/Desktop/Eucalyptus/OpenSet/Models/CAC/{dataset}/"
os.makedirs(model_dir,exist_ok=True)

# %%
for fold in range(n_folds):
    torch.cuda.empty_cache()
    
    gc.collect()

    grafico = AnaliseGraficaVal(f"{model_name}_fold_{fold}", "Eucalyptus cac", dir=f"/home/alexandreselani/Desktop/Eucalyptus/OpenSet/Graficos/CAC/{dataset}/")

    # 4. Modelo, Critério e Otimizador
    model = AlexNet_cac(num_classes,weights=weights)
    anchors = torch.diag(torch.Tensor([alpha for i in range(num_classes)]))	
    model.set_anchors(anchors)
    model = model.to(device)

    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=1e-4)
    criterion = CACLoss

    train_dataloader = data_manager.load_train(transform=weights.transforms(),fold=fold)
    
    val_dataloader = data_manager.load_kkc_val(transform=weights.transforms(),fold=fold)

    for epoch in range(epochs):
        model.train()
        train_loss, train_acc = train_cac(train_dataloader, model, criterion, optimizer,num_classes,lbda)
        
        model.eval()
        val_loss, val_acc = eval_cac(val_dataloader, model, criterion,num_classes,lbda)
        
        print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_loss:.4f} | Acc: {train_acc:.4f} | lr = {optimizer.param_groups[0]['lr']:.6f}")
        print(f"VALIDATION    | Loss: {val_loss:.4f} | Acc: {val_acc:.4f}")

        grafico.addEpochVal(epoch, train_loss, train_acc, val_loss, val_acc)

    grafico.mostraGraficoVal()

    # 7. Salvamento
   
    
    os.makedirs(model_dir,exist_ok=True)
    torch.save(model.state_dict(), f"{model_dir}AlexNet_fold_{fold}.pt")
    print(f"Modelo salvo em {model_dir}")

    del model,optimizer,criterion,grafico,train_dataloader,val_dataloader
# Out:
# Epoch 1/30 | Train Loss: 1.1187 | Acc: 0.7718 | lr = 0.000100
# VALIDATION    | Loss: 0.9421 | Acc: 1.0000
# Epoch 2/30 | Train Loss: 0.8303 | Acc: 0.9887 | lr = 0.000100
# VALIDATION    | Loss: 0.6259 | Acc: 1.0000
# Epoch 3/30 | Train Loss: 0.5406 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.4070 | Acc: 1.0000
# Epoch 4/30 | Train Loss: 0.3576 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.2740 | Acc: 1.0000
# Epoch 5/30 | Train Loss: 0.2268 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.1734 | Acc: 1.0000
# Epoch 6/30 | Train Loss: 0.1388 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0879 | Acc: 1.0000
# Epoch 7/30 | Train Loss: 0.0851 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0646 | Acc: 1.0000
# Epoch 8/30 | Train Loss: 0.0793 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0781 | Acc: 1.0000
# Epoch 9/30 | Train Loss: 0.0773 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0645 | Acc: 1.0000
# Epoch 10/30 | Train Loss: 0.0694 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0553 | Acc: 1.0000
# Epoch 11/30 | Train Loss: 0.0635 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0537 | Acc: 1.0000
# Epoch 12/30 | Train Loss: 0.0618 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0452 | Acc: 1.0000
# Epoch 13/30 | Train Loss: 0.0652 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0396 | Acc: 1.0000
# Epoch 14/30 | Train Loss: 0.0633 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0381 | Acc: 1.0000
# Epoch 15/30 | Train Loss: 0.0638 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0361 | Acc: 1.0000
# Epoch 16/30 | Train Loss: 0.0605 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0356 | Acc: 1.0000
# Epoch 17/30 | Train Loss: 0.0598 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0354 | Acc: 1.0000
# Epoch 18/30 | Train Loss: 0.0586 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0348 | Acc: 1.0000
# Epoch 19/30 | Train Loss: 0.0568 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0356 | Acc: 1.0000
# Epoch 20/30 | Train Loss: 0.0565 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0381 | Acc: 1.0000
# Epoch 21/30 | Train Loss: 0.0592 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0394 | Acc: 1.0000
# Epoch 22/30 | Train Loss: 0.0595 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0385 | Acc: 1.0000
# Epoch 23/30 | Train Loss: 0.0619 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0356 | Acc: 1.0000
# Epoch 24/30 | Train Loss: 0.0566 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0329 | Acc: 1.0000
# Epoch 25/30 | Train Loss: 0.0598 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0314 | Acc: 1.0000
# Epoch 26/30 | Train Loss: 0.0576 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0303 | Acc: 1.0000
# Epoch 27/30 | Train Loss: 0.0557 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0299 | Acc: 1.0000
# Epoch 28/30 | Train Loss: 0.0551 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0301 | Acc: 1.0000
# Epoch 29/30 | Train Loss: 0.0593 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0307 | Acc: 1.0000
# Epoch 30/30 | Train Loss: 0.0539 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0303 | Acc: 1.0000
# Modelo salvo em /home/alexandreselani/Desktop/Eucalyptus/OpenSet/Models/CAC/dataset-1/
# Epoch 1/30 | Train Loss: 1.2494 | Acc: 0.5408 | lr = 0.000100
# VALIDATION    | Loss: 0.9804 | Acc: 1.0000
# Epoch 2/30 | Train Loss: 0.8889 | Acc: 0.9634 | lr = 0.000100
# VALIDATION    | Loss: 0.6801 | Acc: 1.0000
# Epoch 3/30 | Train Loss: 0.5924 | Acc: 0.9944 | lr = 0.000100
# VALIDATION    | Loss: 0.4266 | Acc: 1.0000
# Epoch 4/30 | Train Loss: 0.3924 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.2889 | Acc: 1.0000
# Epoch 5/30 | Train Loss: 0.2795 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.1977 | Acc: 1.0000
# Epoch 6/30 | Train Loss: 0.1888 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.1185 | Acc: 1.0000
# Epoch 7/30 | Train Loss: 0.1132 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0527 | Acc: 1.0000
# Epoch 8/30 | Train Loss: 0.0730 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0635 | Acc: 1.0000
# Epoch 9/30 | Train Loss: 0.0728 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0750 | Acc: 1.0000
# Epoch 10/30 | Train Loss: 0.0760 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0595 | Acc: 1.0000
# Epoch 11/30 | Train Loss: 0.0684 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0448 | Acc: 1.0000
# Epoch 12/30 | Train Loss: 0.0604 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0382 | Acc: 1.0000
# Epoch 13/30 | Train Loss: 0.0585 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0345 | Acc: 1.0000
# Epoch 14/30 | Train Loss: 0.0615 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0326 | Acc: 1.0000
# Epoch 15/30 | Train Loss: 0.0588 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0343 | Acc: 1.0000
# Epoch 16/30 | Train Loss: 0.0599 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0355 | Acc: 1.0000
# Epoch 17/30 | Train Loss: 0.0594 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0352 | Acc: 1.0000
# Epoch 18/30 | Train Loss: 0.0574 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0352 | Acc: 1.0000
# Epoch 19/30 | Train Loss: 0.0568 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0343 | Acc: 1.0000
# Epoch 20/30 | Train Loss: 0.0545 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0328 | Acc: 1.0000
# Epoch 21/30 | Train Loss: 0.0576 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0320 | Acc: 1.0000
# Epoch 22/30 | Train Loss: 0.0531 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0308 | Acc: 1.0000
# Epoch 23/30 | Train Loss: 0.0532 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0311 | Acc: 1.0000
# Epoch 24/30 | Train Loss: 0.0539 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0324 | Acc: 1.0000
# Epoch 25/30 | Train Loss: 0.0539 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0323 | Acc: 1.0000
# Epoch 26/30 | Train Loss: 0.0524 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0308 | Acc: 1.0000
# Epoch 27/30 | Train Loss: 0.0540 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0301 | Acc: 1.0000
# Epoch 28/30 | Train Loss: 0.0520 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0292 | Acc: 1.0000
# Epoch 29/30 | Train Loss: 0.0530 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0277 | Acc: 1.0000
# Epoch 30/30 | Train Loss: 0.0514 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0277 | Acc: 1.0000
# Modelo salvo em /home/alexandreselani/Desktop/Eucalyptus/OpenSet/Models/CAC/dataset-1/
# Epoch 1/30 | Train Loss: 1.1819 | Acc: 0.4197 | lr = 0.000100
# VALIDATION    | Loss: 0.8920 | Acc: 1.0000
# Epoch 2/30 | Train Loss: 0.7331 | Acc: 0.9521 | lr = 0.000100
# VALIDATION    | Loss: 0.4856 | Acc: 1.0000
# Epoch 3/30 | Train Loss: 0.4290 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.2918 | Acc: 1.0000
# Epoch 4/30 | Train Loss: 0.2669 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.1826 | Acc: 1.0000
# Epoch 5/30 | Train Loss: 0.1746 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.1252 | Acc: 1.0000
# Epoch 6/30 | Train Loss: 0.1396 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.1169 | Acc: 1.0000
# Epoch 7/30 | Train Loss: 0.1231 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0955 | Acc: 1.0000
# Epoch 8/30 | Train Loss: 0.0975 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0664 | Acc: 1.0000
# Epoch 9/30 | Train Loss: 0.0779 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0461 | Acc: 1.0000
# Epoch 10/30 | Train Loss: 0.0679 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0364 | Acc: 1.0000
# Epoch 11/30 | Train Loss: 0.0631 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0325 | Acc: 1.0000
# Epoch 12/30 | Train Loss: 0.0616 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0303 | Acc: 1.0000
# Epoch 13/30 | Train Loss: 0.0605 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0273 | Acc: 1.0000
# Epoch 14/30 | Train Loss: 0.0631 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0261 | Acc: 1.0000
# Epoch 15/30 | Train Loss: 0.0579 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0280 | Acc: 1.0000
# Epoch 16/30 | Train Loss: 0.0567 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0282 | Acc: 1.0000
# Epoch 17/30 | Train Loss: 0.0580 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0276 | Acc: 1.0000
# Epoch 18/30 | Train Loss: 0.0583 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0270 | Acc: 1.0000
# Epoch 19/30 | Train Loss: 0.0569 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0259 | Acc: 1.0000
# Epoch 20/30 | Train Loss: 0.0580 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0237 | Acc: 1.0000
# Epoch 21/30 | Train Loss: 0.0553 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0229 | Acc: 1.0000
# Epoch 22/30 | Train Loss: 0.0544 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0231 | Acc: 1.0000
# Epoch 23/30 | Train Loss: 0.0564 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0235 | Acc: 1.0000
# Epoch 24/30 | Train Loss: 0.0587 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0234 | Acc: 1.0000
# Epoch 25/30 | Train Loss: 0.0522 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0229 | Acc: 1.0000
# Epoch 26/30 | Train Loss: 0.0536 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0226 | Acc: 1.0000
# Epoch 27/30 | Train Loss: 0.0551 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0226 | Acc: 1.0000
# Epoch 28/30 | Train Loss: 0.0537 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0221 | Acc: 1.0000
# Epoch 29/30 | Train Loss: 0.0527 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0216 | Acc: 1.0000
# Epoch 30/30 | Train Loss: 0.0527 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0211 | Acc: 1.0000
# Modelo salvo em /home/alexandreselani/Desktop/Eucalyptus/OpenSet/Models/CAC/dataset-1/
# Epoch 1/30 | Train Loss: 1.1113 | Acc: 0.6451 | lr = 0.000100
# VALIDATION    | Loss: 0.8678 | Acc: 1.0000
# Epoch 2/30 | Train Loss: 0.7353 | Acc: 0.9859 | lr = 0.000100
# VALIDATION    | Loss: 0.5300 | Acc: 1.0000
# Epoch 3/30 | Train Loss: 0.4678 | Acc: 0.9944 | lr = 0.000100
# VALIDATION    | Loss: 0.3264 | Acc: 1.0000
# Epoch 4/30 | Train Loss: 0.2997 | Acc: 0.9944 | lr = 0.000100
# VALIDATION    | Loss: 0.2036 | Acc: 1.0000
# Epoch 5/30 | Train Loss: 0.1816 | Acc: 0.9915 | lr = 0.000100
# VALIDATION    | Loss: 0.1008 | Acc: 1.0000
# Epoch 6/30 | Train Loss: 0.0952 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0447 | Acc: 1.0000
# Epoch 7/30 | Train Loss: 0.0817 | Acc: 0.9944 | lr = 0.000100
# VALIDATION    | Loss: 0.0650 | Acc: 1.0000
# Epoch 8/30 | Train Loss: 0.0925 | Acc: 0.9944 | lr = 0.000100
# VALIDATION    | Loss: 0.0548 | Acc: 1.0000
# Epoch 9/30 | Train Loss: 0.0730 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0448 | Acc: 1.0000
# Epoch 10/30 | Train Loss: 0.0736 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0422 | Acc: 1.0000
# Epoch 11/30 | Train Loss: 0.0684 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0389 | Acc: 1.0000
# Epoch 12/30 | Train Loss: 0.0677 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0336 | Acc: 1.0000
# Epoch 13/30 | Train Loss: 0.0673 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0304 | Acc: 1.0000
# Epoch 14/30 | Train Loss: 0.0637 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0303 | Acc: 1.0000
# Epoch 15/30 | Train Loss: 0.0608 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0311 | Acc: 1.0000
# Epoch 16/30 | Train Loss: 0.0624 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0319 | Acc: 1.0000
# Epoch 17/30 | Train Loss: 0.0596 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0320 | Acc: 1.0000
# Epoch 18/30 | Train Loss: 0.0574 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0315 | Acc: 1.0000
# Epoch 19/30 | Train Loss: 0.0589 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0298 | Acc: 1.0000
# Epoch 20/30 | Train Loss: 0.0616 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0290 | Acc: 1.0000
# Epoch 21/30 | Train Loss: 0.0554 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0288 | Acc: 1.0000
# Epoch 22/30 | Train Loss: 0.0589 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0291 | Acc: 1.0000
# Epoch 23/30 | Train Loss: 0.0553 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0291 | Acc: 1.0000
# Epoch 24/30 | Train Loss: 0.0577 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0292 | Acc: 1.0000
# Epoch 25/30 | Train Loss: 0.0543 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0293 | Acc: 1.0000
# Epoch 26/30 | Train Loss: 0.0554 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0283 | Acc: 1.0000
# Epoch 27/30 | Train Loss: 0.0551 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0277 | Acc: 1.0000
# Epoch 28/30 | Train Loss: 0.0550 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0278 | Acc: 1.0000
# Epoch 29/30 | Train Loss: 0.0582 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.0276 | Acc: 1.0000
# Epoch 30/30 | Train Loss: 0.0568 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0274 | Acc: 1.0000
# Modelo salvo em /home/alexandreselani/Desktop/Eucalyptus/OpenSet/Models/CAC/dataset-1/
# Epoch 1/30 | Train Loss: 1.0197 | Acc: 0.7360 | lr = 0.000100
# VALIDATION    | Loss: 0.8735 | Acc: 1.0000
# Epoch 2/30 | Train Loss: 0.7678 | Acc: 0.9972 | lr = 0.000100
# VALIDATION    | Loss: 0.6033 | Acc: 1.0000
# Epoch 3/30 | Train Loss: 0.5261 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.4208 | Acc: 1.0000
# Epoch 4/30 | Train Loss: 0.3645 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.3020 | Acc: 1.0000
# Epoch 5/30 | Train Loss: 0.2595 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.2098 | Acc: 1.0000
# Epoch 6/30 | Train Loss: 0.1709 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.1292 | Acc: 1.0000
# Epoch 7/30 | Train Loss: 0.1030 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0886 | Acc: 1.0000
# Epoch 8/30 | Train Loss: 0.0784 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0781 | Acc: 1.0000
# Epoch 9/30 | Train Loss: 0.0743 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0713 | Acc: 1.0000
# Epoch 10/30 | Train Loss: 0.0649 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0585 | Acc: 1.0000
# Epoch 11/30 | Train Loss: 0.0619 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0510 | Acc: 1.0000
# Epoch 12/30 | Train Loss: 0.0626 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0500 | Acc: 1.0000
# Epoch 13/30 | Train Loss: 0.0589 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0466 | Acc: 1.0000
# Epoch 14/30 | Train Loss: 0.0570 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0463 | Acc: 1.0000
# Epoch 15/30 | Train Loss: 0.0608 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0456 | Acc: 1.0000
# Epoch 16/30 | Train Loss: 0.0563 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0447 | Acc: 1.0000
# Epoch 17/30 | Train Loss: 0.0537 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0428 | Acc: 1.0000
# Epoch 18/30 | Train Loss: 0.0568 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0419 | Acc: 1.0000
# Epoch 19/30 | Train Loss: 0.0555 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0409 | Acc: 1.0000
# Epoch 20/30 | Train Loss: 0.0563 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0398 | Acc: 1.0000
# Epoch 21/30 | Train Loss: 0.0512 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0384 | Acc: 1.0000
# Epoch 22/30 | Train Loss: 0.0550 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0382 | Acc: 1.0000
# Epoch 23/30 | Train Loss: 0.0564 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0385 | Acc: 1.0000
# Epoch 24/30 | Train Loss: 0.0538 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0382 | Acc: 1.0000
# Epoch 25/30 | Train Loss: 0.0541 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0372 | Acc: 1.0000
# Epoch 26/30 | Train Loss: 0.0533 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0364 | Acc: 1.0000
# Epoch 27/30 | Train Loss: 0.0547 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0362 | Acc: 1.0000
# Epoch 28/30 | Train Loss: 0.0539 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0354 | Acc: 1.0000
# Epoch 29/30 | Train Loss: 0.0530 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0351 | Acc: 1.0000
# Epoch 30/30 | Train Loss: 0.0564 | Acc: 1.0000 | lr = 0.000100
# VALIDATION    | Loss: 0.0352 | Acc: 1.0000
# Modelo salvo em /home/alexandreselani/Desktop/Eucalyptus/OpenSet/Models/CAC/dataset-1/

# %% [markdown]
# # Testing

# %%
# import numpy as np
# from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay
# from Utils import AnaliseGraficaVal, train, eval, fix_random_seed, predict

# cm = np.zeros((num_classes,num_classes),dtype=int)

# for fold in range(n_folds):
#     model = Alexnet(num_classes=num_classes)
#     model.load_state_dict(torch.load(f"{model_dir}AlexNet_fold_{fold}.pt"))
#     model.to(device)
#     test_dataloader = data_manager.load_test(fold,transform=weights.transforms())

#     y_true = []
#     for _,y in test_dataloader:
#         y_true.append(y)

#     #print(y_true)
#     y_true = torch.concat(y_true)
#     y_pred = predict(test_dataloader,model)

    
#     y_true = y_true.cpu()
#     y_pred = y_pred.cpu()
    
#     cm += confusion_matrix(y_true,y_pred)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=[c for c in range(num_classes)])
disp.plot(ax=ax)
plt.title(f"Confusion matrix - {model_name}: {dataset}")
image_name = f"Confusion matrix - {model_name}: {dataset}.png"
plt.savefig(image_name, dpi=300, bbox_inches='tight')
plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 import matplotlib.pyplot as plt
#       3 fig, ax = plt.subplots(figsize=(10, 8))
# ----> 4 disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=[c for c in range(num_classes)])
#       5 disp.plot(ax=ax)
#       6 plt.title(f"Confusion matrix - {model_name}: {dataset}")
#
# NameError: name 'ConfusionMatrixDisplay' is not defined
